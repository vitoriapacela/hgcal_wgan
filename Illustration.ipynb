# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

n_samples=500

fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(211, projection='3d')
ax.plot(np.random.random(n_samples), np.random.random(n_samples), np.random.random(n_samples), 'o', alpha=0.4, color='purple')
ax.grid(True)

ax.set_yticklabels([])
ax.set_xticklabels([])
ax.set_zticklabels([])

ax.set_xlabel(r'$\eta$ bin', size=30)
ax.set_ylabel('layer', size=30)
ax.set_zlabel(r'$\phi$ bin', size=30)
plt.show()
