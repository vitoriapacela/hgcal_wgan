# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
from plots import read_h5, plotLoss, losses, plotLossVal, lossesVal, plotLoss2, losses2, plotRealFake, lossesRealFake

# %%
current = "../trial37/bs_128_lr_0.00005_latent_100_ncritic_5_clip_0.01_losses.h5"

# %%
losses(current)

# %%
discriminator, discriminator_fake, discriminator_real, generator = read_h5(current)

# %%
plotWassLoss(discriminator)

# %%
plotWassLoss(generator)

# %%
plotEnergyLoss(discriminator)

# %%
plotEnergyLoss(generator)

# %%
### Plot losses inverted!
def losses(h5file):
    # (str) h5file: name of the file containing the loss arrays
    discriminator, discriminator_fake, discriminator_real, generator = read_h5(h5file)
    
    plotLoss(discriminator, "Discriminator")
    plotLoss(discriminator_real, "Discriminator_real")
    plotLoss(discriminator_fake, "Discriminator_fake")
    plotLoss(generator, "Generator")

# %%
#losses(current)

# %%
#losses("val_trial2_losses.h5")

# %%
#val_current = "trial27/val_bs_128_lr_0.00005_latent_100_ncritic_5_clip_0.01_losses.h5"

# %%
#lossesVal(current, val_current)

# %%
losses2("../trial23/val_bs_128_lr_0.00005_latent_100_ncritic_5_clip_0.01_shuffle_losses.h5", current)

# %%
#losses2("/nfshome/vitoriabp/Keras-GAN/wgan/trial2_batch_size_32_epochs_4000/trial2_losses.h5", "/nfshome/vitoriabp/Keras-GAN/wgan/trial3_batch_size_128_epochs_2000/trial3_bs_128_losses.h5")

# %%
#losses2("/nfshome/vitoriabp/Keras-GAN/wgan/trial3_batch_size_128_epochs_2000/trial3_bs_128_losses.h5", current)

# %%
#from plots import plotLoss3, losses3

# %%
#losses3("/nfshome/vitoriabp/Keras-GAN/wgan/trial2_batch_size_32_epochs_4000/trial2_losses.h5", current, "/nfshome/vitoriabp/Keras-GAN/wgan/trial3_batch_size_128_epochs_2000/trial3_bs_128_losses.h5")

# %%
lossesRealFake(current)
